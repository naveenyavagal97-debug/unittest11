# %% [raw]
# q 1) Two dice are thrown .find the probability  of getting a 3 on the first die and a 5 on the second die?
#
# Ans: probaility =sum of observation/possibility.  (probability formula)
#      if we thrown die once, possibilities are [1,2,3,4,5,6] total 6 possibilities we get it.
#
#      if we thrown a first die getting a 3 means 1/6----- (by observing possibilities we get only once 3)
#
#      if we thrown a second die getting a 5 means 1/6---  (by observing possibilities we get only once 5)
#
#      probaility =sum of observation/possibility
#                 =1/6*1/6
#
#      total probability of adding both fist dice and second dice is = 1/6*1/6=1/36.

# %% [raw]
# q 2) find the probability of not getting 6 when a die is thrown?
#
# Ans: probaility =sum of observation/possibility.  (probability formula)
#      if we thrown die once,  possibilities are [1,2,3,4,5,6] total 6 possibilities we get it.
#
#     in question they are asking not getting 6 means observations are [1,2,3,4,5] totally 5 observation we get it
#
#      probaility =sum of observation/possibility
#
#      proabability =5/6 .

# %% [raw]
# q 4 ) A committee of 2 people is choosen from 4 men and 3 women ,Find the probability that both are women?
#
# Ans: Total people = 4 men + 3 women = 7
#
#      Two ways to choose a committee of 2 people = 7C2
#                                                 =7*6 / 2*1
#                                                 =42/2
#                                                 =21
#
#
#    favoable ways ( both are women)
#    number of women=3
#    ways to choose 2 women
#    3C2
#    3*2/2*1
#    6/2
#    3
#
# Probability that both are women
#
# P= Favourable outcome/Total Outcome
# =3/21
# =1/7

# %% [raw]
# q 5) Define sample space and events with an example.
#
# Ans: Sample space is the set of all possible outcomes of a random experiment.
#      it is usually denoted by S.
#
#   ex: if a die is thrown once, the possible outcomes are
#      S=[1,2,3,4,5,6]
#
#
#  Event: An Event is any subset of the sample space. in simple words, an event is a specific outcome or a group of outcomes we are interested in
#
#
# Ex:   From the Sample Space of a die thrown
#
#      Event A: Getting an even number
#
#     A=[2,4,6]
#
#     Event B : Getting a number greater than 4
#
#    B=[5,6]
#
#  Both A and B are Events because they are subsets of the sample space S.

# %% [raw]
# q 7) what is bayes theorem?
#
# Ans: Baye's theroem is a rule in probability that helps us update the probability of an event when we get new information (evidence)
#
#     Formula:  P(A|B) P(B|A) P(A)/P(B)
#
#               P(A)-- PRIOR PROBABILITY , probability of event A  before seeing evidence B.
#
#               P(B|A)--LIKELIHOOD ,  probability of observing B if A has already happened.
#
#               P(B)-- MARGINAL PROBABILITY , totla probability of B.
#
#               P(A|B)--POSTERIOR PROBABILITY,  updated probability of A after observing B

# %% [raw]
# q 8) what is difference between PDF and PMF (give example with code)
#
# Ans: PMF --- PROBABILITY MASS FUNCTION
#         it used for discrete random variables (0,1,2,3,4, ......)
#
#          it gives probability of exact values.
#          sum of all probabilities =1
#          ex: no of heads when tossing a coin.
#
#         let X=outcome of fair coin
#         P(X=0) = 0.5 ( TAIL)
#         P(X=1) = 0.5 ( HEAD )

# %%
 from scipy.stats import binom
pmf_value=binom.pmf(1, n=1, p=0.5)
print("PMF:",pmf_value)
# Out:
# PMF: 0.5

# %% [raw]
#   PDF --- PROBABILITY DENSITY FUNCTION
#
# used for contionous random variables (values are a uncountable :real numbers)
#
#    Probability at an exact value=0
#    probability is found over an interval
#    area under curve=1
#    Ex: height,weight,time
#
# Let  X= height of people
# Height can be any real value, so we use PDF.

# %%
from scipy.stats import norm
# PDF value at x =170 for mean=170, std=10
pdf_value=norm.pdf(170 , loc=170, scale=10)
print("PDF:",pdf_value)
# Out:
# PDF: 0.03989422804014327

# %% [raw]
# q 3) a disease affects 5% of the population . A test detects the disease correctly 90% of the time. it falsely shows posiive for 10% of healthy people.
#     If a Person tests Positive, what is the probability  that actually have the disease?
#
# Ans: Probability a person has the disease
#       P(D)= 5%---5/100--0.05
#
#    Probability a person is healty
#    P(H)=0.95
#
#  Test correctly detects disease ( sensitivity)
#  P(+D)-- 90/100---0.90
#
# Test shows false positive for healthy people.
#
# P(+H)--10/100---0.10
#
# probability of testing positive
#
# P(+)  =P(+D)*P(D) + P(+H) P(H)
#       =(0.90*0.05)+(0.10*0.95)
#       = 0.045 + 0.095
#       = 0.14
#
# Apply Baye's theorem
#
# P(D|+)= P(D+) *P(D) /P(+)
#       = (0.90*0.05) / 0.14
#       = 0.045/0.14
#       =0.3214
#
# Probability of that actually have the disease is
#  P(D|+)= 0.3214  32.14%

# %%
q 5) A machine produces items where the number of detective items per batch is given below .find the probability that batch contains no defects 

Ans: This is a discrrete probability distribution (PMF) 

    Let X= number of defective items in a batch 

X(defects)   0     1      2
P(X=x)      0.50   0.35   0.15  

 total=0.50+0.35+0.15= 1 ( it gives the probability value exactly 1, so it is PMF)

find the Probability that the batch contains no defects.

no defects means X=0

P( no defects ) = P ( X = 0 )

P(X = 0) = 0.50  OR 50%.

THERE IS A 50% CHANCE THAT A RANDOMLY SELECTED BATCH WILL HAVE NO DEFECTIVE ITEMS.
