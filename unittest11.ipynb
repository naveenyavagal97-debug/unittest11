# %% [raw]
# Q 3: what is encoding and why do we need it?

# %% [raw]
# ans: Encoding is the process of converting categorical (text or non-numeric) data into a numeric form so that a computer or machine learning alogorithem can understand and use it.
#
# example: ( text data):
#
# Gender= Male, Female
#
# after encoding
#
# Male=1
# Feamle=0
#
# most machine learning algorithms work only with numbers, not text.Encoding is needed because:
#
# 1) computer understand numbers, not text: alogorithms perform mathematical calculations, which require numeric input.
# 2)to train machine learning models: data like city names,gender,product type etc, must be converted to numbers.
# 3)to improve model performance: proper encoding helps models learn patterns correctly and avoid confusion.
# 4)many datasets contain categories that must be encoded before analysis.
#
# simple ex:
#
# name    city
# A       Delhi
# B       Pune
#
#
# after encoding:
#
# Name    city
# A        0
# B        1
#
# now the model can process it.
#
# types of encoding
#
# 1)label encoding: Assigns a unique number to each category
#  ex: Re0, Blue=1, Green=2
#
# 2)one hot encoding:  Creates seperate column for each category.
# Ex:  Red--[1,0,0]
#      Blue--[0,1,0]
#      Green--[0,0,1]

# %% [raw]
# q:4) what is scaling ? why do we scale feaures?

# %% [raw]
# Ans:Scaling is a data preprocessing technique used to bring numerical features to the same range or scale without changing their meaning
#
# it transforms feature values so that large values do not dominate smaller ones.
#
# we scale feature because
#
# 1) Different features have different units and ranges
#
# ex:
# Age--18 to 60
# salary-- 20,000 to 2,00,000
#
# salary values are much larger and can dominate the model
#
#
# 2) Many alogorithms are distance-based algorithms like
#
# KNN
# k-means Clustering
# support vector machines (svm)
# linear & logistic regression ( gradient descent)
#
# These algorithms give better results when features are on the same scale
#
# 3)faster and better convergence:
# scaling helps optimization algorithms converges faster  and more accurately.
#
# 4)prevents bias towards large values:
# without scaling, features with large magnitudes influence predictions more
#
# common feature of scaling techniques
#
# 1. Min-Max Scaling
# 2.Standardization ( z-score scaling)
# 3.Robust scaling

# %%
# 1) 
from scipy.stats import mannwhitneyu

group1=[7,8,6,9,7]
group2=[5,6,4,7,5]

u_statistic, p_value=mannwhitneyu(group1,group2, alternative='two-sided')
print("U Statistic:",u_statistic)
print("P-value:",p_value)
# Out:
# U Statistic: 22.5
# P-value: 0.043219587173790874

# %% [raw]
# H0 (Null Hypothesis):customer satisfaction is same for both groups.
# H1 (ALternative Hypothesis):customer satisfaction differs between the two groups.

# %% [raw]
# p value <0.05--- reject H0
# p value >=0.05-- fail to reject H0.
#
#     The p-value will be greater than 0.05 , There is no statistically significant difference in customer satisfaction between Group 1 and Group 2,
# even though Group 1 has higher rating on average ,so it fails to reject H0.

# %%
# 2)
from scipy.stats import shapiro 
spending=[1200,1500,1800,1700,1600,1550,1650,1750]

statstic,p_value=shapiro(spending)
print("Shapiro-Wilk Statisic:", statstic)
print("P-value:",p_value)
# Out:
# Shapiro-Wilk Statisic: 0.8982337876961448
# P-value: 0.2785402226945662

# %% [raw]
# if p-value>=0.05-- fail to reject H0-- data is normally distribute.
# if p-value<0.05-- Reject H0-- data is not normally distribute.
#
#
# The P value will be greater than 0.05 therefore customer spending  data follows a normal distribution.
